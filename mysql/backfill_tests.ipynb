# %%
import requests
from bs4 import BeautifulSoup

def get_grid_conditions(grid_num: int | None = None) -> list[str]:
    base_url = 'https://www.immaculategrid.com'
    var_url = f"/grid-{grid_num}"
    url = base_url + var_url if grid_num else base_url
    response = requests.get(url)
    if response.status_code != 200:
        return []
    soup = BeautifulSoup(response.content, 'html.parser')
    condition_pairs = [button.get('aria-label') for button in soup.find_all('button', class_='focus:bg-yellow-200 w-full h-full')]
    ret = []
    for pair in condition_pairs:
        cond1, cond2 = pair.split(" + ")
        cond1 = " ".join(cond1.split())
        cond2 = " ".join(cond2.split())
        ret.append([cond1, cond2])
    return ret

def get_max_grid_number() -> int:
    url = 'https://www.immaculategrid.com'

    response = requests.get(url)
    if response.status_code != 200:
        return -1
    
    soup = BeautifulSoup(response.content, 'html.parser')
    
    grid_num = int(
        soup
        .find('div', class_="uppercase font-medium")
        .text
        .split(" ")[-1][1:])
    
    return grid_num

def backfill_IM_conditions(limit: int = 10) -> list[list[str]]:
    max_grid_num = get_max_grid_number()
    return [
        get_grid_conditions(grid)
        for grid in reversed(range(max_grid_num - limit + 1, max_grid_num + 1))
    ]

# %%
grid_backfill = backfill_IM_conditions(limit=get_max_grid_number())

# %%
st = set()
for date in grid_backfill:
    for row in date:
        print(row)
        for cond in row:
            st.add(cond)
lst_st = list(st)
# Out:
# ['Los Angeles Angels', 'Pittsburgh Pirates']
# ['Los Angeles Angels', 'Baltimore Orioles']
# ['Los Angeles Angels', 'Played Shortstop min. 1 game']
# ['New York Yankees', 'Pittsburgh Pirates']
# ['New York Yankees', 'Baltimore Orioles']
# ['New York Yankees', 'Played Shortstop min. 1 game']
# ['.300+ AVG Season Batting', 'Pittsburgh Pirates']
# ['.300+ AVG Season Batting', 'Baltimore Orioles']
# ['.300+ AVG Season Batting', 'Played Shortstop min. 1 game']
# ['Oakland Athletics', 'Boston Red Sox']
# ['Oakland Athletics', 'Kansas City Royals']
# ['Oakland Athletics', 'Born Outside US 50 States and DC']
# ['Houston Astros', 'Boston Red Sox']
# ['Houston Astros', 'Kansas City Royals']
# ['Houston Astros', 'Born Outside US 50 States and DC']
# ['Washington Nationals', 'Boston Red Sox']
# ['Washington Nationals', 'Kansas City Royals']
# ['Washington Nationals', 'Born Outside US 50 States and DC']
# ['Atlanta Braves', 'San Diego Padres']
# ['Atlanta Braves', 'Chicago White Sox']
# ['Atlanta Braves', '2000+ Hits Career Batting']
# ['Miami Marlins', 'San Diego Padres']
# ['Miami Marlins', 'Chicago White Sox']
# ['Miami Marlins', '2000+ Hits Career Batting']
# ['San Francisco Giants', 'San Diego Padres']
# ['San Francisco Giants', 'Chicago White Sox']
# ['San Francisco Giants', '2000+ Hits Career Batting']
# ['Milwaukee Brewers', 'New York Mets']
# ['Milwaukee Brewers', 'Seattle Mariners']
# ['Milwaukee Brewers', '6+ WAR Season']
# ['Detroit Tigers', 'New York Mets']
# ['Detroit Tigers', 'Seattle Mariners']
# ['Detroit Tigers', '6+ WAR Season']
# ['30+ SB Season', 'New York Mets']
# ['30+ SB Season', 'Seattle Mariners']
# ['30+ SB Season', '6+ WAR Season']
# ['St. Louis Cardinals', 'Los Angeles Dodgers']
# ['St. Louis Cardinals', 'Philadelphia Phillies']
# ['St. Louis Cardinals', 'All Star']
# ['Arizona Diamondbacks', 'Los Angeles Dodgers']
# ['Arizona Diamondbacks', 'Philadelphia Phillies']
# ['Arizona Diamondbacks', 'All Star']
# ['Played Catcher min. 1 game', 'Los Angeles Dodgers']
# ['Played Catcher min. 1 game', 'Philadelphia Phillies']
# ['Played Catcher min. 1 game', 'All Star']
# ['Cleveland Guardians', 'Texas Rangers']
# ['Cleveland Guardians', 'New York Yankees']
# ['Cleveland Guardians', '30+ HR Season Batting']
# ['Minnesota Twins', 'Texas Rangers']
# ['Minnesota Twins', 'New York Yankees']
# ['Minnesota Twins', '30+ HR Season Batting']
# ['Played Center Field min. 1 game', 'Texas Rangers']
# ['Played Center Field min. 1 game', 'New York Yankees']
# ['Played Center Field min. 1 game', '30+ HR Season Batting']
# ['200+ K Season Pitching', '≤ 3.00 ERA Season']
# ['200+ K Season Pitching', '10+ Win Season Pitching']
# ['200+ K Season Pitching', 'First Round Draft Pick']
# ['Silver Slugger', '≤ 3.00 ERA Season']
# ['Silver Slugger', '10+ Win Season Pitching']
# ['Silver Slugger', 'First Round Draft Pick']
# ['Gold Glove', '≤ 3.00 ERA Season']
# ['Gold Glove', '10+ Win Season Pitching']
# ['Gold Glove', 'First Round Draft Pick']
# ['Boston Red Sox', 'Chicago Cubs']
# ['Boston Red Sox', 'Cincinnati Reds']
# ['Boston Red Sox', '500+ HR Career Batting']
# ['Baltimore Orioles', 'Chicago Cubs']
# ['Baltimore Orioles', 'Cincinnati Reds']
# ['Baltimore Orioles', '500+ HR Career Batting']
# ['Played Third Base min. 1 game', 'Chicago Cubs']
# ['Played Third Base min. 1 game', 'Cincinnati Reds']
# ['Played Third Base min. 1 game', '500+ HR Career Batting']
# ['Atlanta Braves', 'New York Mets']
# ['Atlanta Braves', 'San Francisco Giants']
# ['Atlanta Braves', 'Only One Team']
# ['Los Angeles Dodgers', 'New York Mets']
# ['Los Angeles Dodgers', 'San Francisco Giants']
# ['Los Angeles Dodgers', 'Only One Team']
# ['Hall of Fame', 'New York Mets']
# ['Hall of Fame', 'San Francisco Giants']
# ['Hall of Fame', 'Only One Team']
# ['Pittsburgh Pirates', 'Seattle Mariners']
# ['Pittsburgh Pirates', 'Houston Astros']
# ['Pittsburgh Pirates', '100+ RBI Season Batting']
# ['Toronto Blue Jays', 'Seattle Mariners']
# ['Toronto Blue Jays', 'Houston Astros']
# ['Toronto Blue Jays', '100+ RBI Season Batting']
# ['Played Shortstop min. 1 game', 'Seattle Mariners']
# ['Played Shortstop min. 1 game', 'Houston Astros']
# ['Played Shortstop min. 1 game', '100+ RBI Season Batting']
# ['Washington Nationals', 'Los Angeles Angels']
# ['Washington Nationals', 'Texas Rangers']
# ['Washington Nationals', 'Played Outfield min. 1 game']
# ['St. Louis Cardinals', 'Los Angeles Angels']
# ['St. Louis Cardinals', 'Texas Rangers']
# ['St. Louis Cardinals', 'Played Outfield min. 1 game']
# ['2000+ Hits Career Batting', 'Los Angeles Angels']
# ['2000+ Hits Career Batting', 'Texas Rangers']
# ['2000+ Hits Career Batting', 'Played Outfield min. 1 game']
# ['Baltimore Orioles', 'Chicago White Sox']
# ['Baltimore Orioles', 'Detroit Tigers']
# ['Baltimore Orioles', 'Played First Base min. 1 game']
# ['Oakland Athletics', 'Chicago White Sox']
# ['Oakland Athletics', 'Detroit Tigers']
# ['Oakland Athletics', 'Played First Base min. 1 game']
# ['New York Yankees', 'Chicago White Sox']
# ['New York Yankees', 'Detroit Tigers']
# ['New York Yankees', 'Played First Base min. 1 game']
# ['Atlanta Braves', 'Kansas City Royals']
# ['Atlanta Braves', 'Philadelphia Phillies']
# ['Atlanta Braves', '30+ HR Season Batting']
# ['Tampa Bay Rays', 'Kansas City Royals']
# ['Tampa Bay Rays', 'Philadelphia Phillies']
# ['Tampa Bay Rays', '30+ HR Season Batting']
# ['All Star', 'Kansas City Royals']
# ['All Star', 'Philadelphia Phillies']
# ['All Star', '30+ HR Season Batting']
# ['Boston Red Sox', 'San Francisco Giants']
# ['Boston Red Sox', 'Threw a No-Hitter']
# ['Boston Red Sox', '200+ Hits Season Batting']
# ['MVP', 'San Francisco Giants']
# ['MVP', 'Threw a No-Hitter']
# ['MVP', '200+ Hits Season Batting']
# ['6+ WAR Season', 'San Francisco Giants']
# ['6+ WAR Season', 'Threw a No-Hitter']
# ['6+ WAR Season', '200+ Hits Season Batting']
# ['Milwaukee Brewers', 'San Diego Padres']
# ['Milwaukee Brewers', 'Los Angeles Angels']
# ['Milwaukee Brewers', 'Born Outside US 50 States and DC']
# ['Los Angeles Dodgers', 'San Diego Padres']
# ['Los Angeles Dodgers', 'Los Angeles Angels']
# ['Los Angeles Dodgers', 'Born Outside US 50 States and DC']
# ['300+ HR Career Batting', 'San Diego Padres']
# ['300+ HR Career Batting', 'Los Angeles Angels']
# ['300+ HR Career Batting', 'Born Outside US 50 States and DC']
# ['Minnesota Twins', 'New York Mets']
# ['Minnesota Twins', 'Toronto Blue Jays']
# ['Minnesota Twins', '20+ Win Season Pitching']
# ['Cincinnati Reds', 'New York Mets']
# ['Cincinnati Reds', 'Toronto Blue Jays']
# ['Cincinnati Reds', '20+ Win Season Pitching']
# ['Cleveland Guardians', 'New York Mets']
# ['Cleveland Guardians', 'Toronto Blue Jays']
# ['Cleveland Guardians', '20+ Win Season Pitching']
# ['New York Yankees', 'Chicago Cubs']
# ['New York Yankees', 'Played Catcher min. 1 game']
# ['New York Yankees', 'Pitched min. 1 game']
# ['Colorado Rockies', 'Chicago Cubs']
# ['Colorado Rockies', 'Played Catcher min. 1 game']
# ['Colorado Rockies', 'Pitched min. 1 game']
# ['Chicago White Sox', 'Chicago Cubs']
# ['Chicago White Sox', 'Played Catcher min. 1 game']
# ['Chicago White Sox', 'Pitched min. 1 game']
# ['Houston Astros', 'Texas Rangers']
# ['Houston Astros', 'St. Louis Cardinals']
# ['Houston Astros', 'Played Second Base min. 1 game']
# ['Pittsburgh Pirates', 'Texas Rangers']
# ['Pittsburgh Pirates', 'St. Louis Cardinals']
# ['Pittsburgh Pirates', 'Played Second Base min. 1 game']
# ['Silver Slugger', 'Texas Rangers']
# ['Silver Slugger', 'St. Louis Cardinals']
# ['Silver Slugger', 'Played Second Base min. 1 game']
# ['Atlanta Braves', 'Washington Nationals']
# ['Atlanta Braves', '100+ RBI Season Batting']
# ['Atlanta Braves', 'Hall of Fame']
# ['Seattle Mariners', 'Washington Nationals']
# ['Seattle Mariners', '100+ RBI Season Batting']
# ['Seattle Mariners', 'Hall of Fame']
# ['Miami Marlins', 'Washington Nationals']
# ['Miami Marlins', '100+ RBI Season Batting']
# ['Miami Marlins', 'Hall of Fame']
# ['Detroit Tigers', 'Philadelphia Phillies']
# ['Detroit Tigers', '30+ Save Season Pitching']
# ['Detroit Tigers', 'Played Shortstop min. 1 game']
# ['San Francisco Giants', 'Philadelphia Phillies']
# ['San Francisco Giants', '30+ Save Season Pitching']
# ['San Francisco Giants', 'Played Shortstop min. 1 game']
# ['Oakland Athletics', 'Philadelphia Phillies']
# ['Oakland Athletics', '30+ Save Season Pitching']
# ['Oakland Athletics', 'Played Shortstop min. 1 game']
# ['200+ Hits Season Batting', '100+ Run Season Batting']
# ['200+ Hits Season Batting', '30+ SB Season']
# ['200+ Hits Season Batting', '.300+ AVG Season Batting']
# ['Rookie of the Year', '100+ Run Season Batting']
# ['Rookie of the Year', '30+ SB Season']
# ['Rookie of the Year', '.300+ AVG Season Batting']
# ['Played Third Base min. 1 game', '100+ Run Season Batting']
# ['Played Third Base min. 1 game', '30+ SB Season']
# ['Played Third Base min. 1 game', '.300+ AVG Season Batting']
# ['Baltimore Orioles', 'St. Louis Cardinals']
# ['Baltimore Orioles', 'Cleveland Guardians']
# ['Baltimore Orioles', '30+ HR Season Batting']
# ['Kansas City Royals', 'St. Louis Cardinals']
# ['Kansas City Royals', 'Cleveland Guardians']
# ['Kansas City Royals', '30+ HR Season Batting']
# ['Boston Red Sox', 'St. Louis Cardinals']
# ['Boston Red Sox', 'Cleveland Guardians']
# ['Boston Red Sox', '30+ HR Season Batting']
# ['New York Mets', 'New York Yankees']
# ['New York Mets', 'Toronto Blue Jays']
# ['New York Mets', '≤ 3.00 ERA Season']
# ['Los Angeles Angels', 'New York Yankees']
# ['Los Angeles Angels', 'Toronto Blue Jays']
# ['Los Angeles Angels', '≤ 3.00 ERA Season']
# ['Los Angeles Dodgers', 'New York Yankees']
# ['Los Angeles Dodgers', 'Toronto Blue Jays']
# ['Los Angeles Dodgers', '≤ 3.00 ERA Season']
# ['2000+ Hits Career Batting', '40+ WAR Career']
# ['2000+ Hits Career Batting', '500+ HR Career Batting']
# ['2000+ Hits Career Batting', 'Gold Glove']
# ['.300+ AVG Career Batting', '40+ WAR Career']
# ['.300+ AVG Career Batting', '500+ HR Career Batting']
# ['.300+ AVG Career Batting', 'Gold Glove']
# ['Born Outside US 50 States and DC', '40+ WAR Career']
# ['Born Outside US 50 States and DC', '500+ HR Career Batting']
# ['Born Outside US 50 States and DC', 'Gold Glove']
# ['Pittsburgh Pirates', 'San Diego Padres']
# ['Pittsburgh Pirates', 'Milwaukee Brewers']
# ['Pittsburgh Pirates', 'Played Outfield min. 1 game']
# ['Chicago White Sox', 'San Diego Padres']
# ['Chicago White Sox', 'Milwaukee Brewers']
# ['Chicago White Sox', 'Played Outfield min. 1 game']
# ['All Star', 'San Diego Padres']
# ['All Star', 'Milwaukee Brewers']
# ['All Star', 'Played Outfield min. 1 game']
# ['Minnesota Twins', 'Washington Nationals']
# ['Minnesota Twins', 'MVP']
# ['Minnesota Twins', 'Played Center Field min. 1 game']
# ['Chicago Cubs', 'Washington Nationals']
# ['Chicago Cubs', 'MVP']
# ['Chicago Cubs', 'Played Center Field min. 1 game']
# ['Silver Slugger', 'Washington Nationals']
# ['Silver Slugger', 'MVP']
# ['Silver Slugger', 'Played Center Field min. 1 game']
# ['New York Yankees', 'Oakland Athletics']
# ['New York Yankees', 'San Francisco Giants']
# ['New York Yankees', 'Only One Team']
# ['Miami Marlins', 'Oakland Athletics']
# ['Miami Marlins', 'San Francisco Giants']
# ['Miami Marlins', 'Only One Team']
# ['Cincinnati Reds', 'Oakland Athletics']
# ['Cincinnati Reds', 'San Francisco Giants']
# ['Cincinnati Reds', 'Only One Team']
# ['2000+ K Career Pitching', '200+ Wins Career Pitching']
# ['2000+ K Career Pitching', 'Cy Young']
# ['2000+ K Career Pitching', 'Hall of Fame']
# ['10+ Win Season Pitching', '200+ Wins Career Pitching']
# ['10+ Win Season Pitching', 'Cy Young']
# ['10+ Win Season Pitching', 'Hall of Fame']
# ['Threw a No-Hitter', '200+ Wins Career Pitching']
# ['Threw a No-Hitter', 'Cy Young']
# ['Threw a No-Hitter', 'Hall of Fame']
# ['Atlanta Braves', 'Texas Rangers']
# ['Atlanta Braves', '.300+ AVG Season Batting']
# ['Atlanta Braves', '300+ HR Career Batting']
# ['Boston Red Sox', 'Texas Rangers']
# ['Boston Red Sox', '.300+ AVG Season Batting']
# ['Boston Red Sox', '300+ HR Career Batting']
# ['First Round Draft Pick', 'Texas Rangers']
# ['First Round Draft Pick', '.300+ AVG Season Batting']
# ['First Round Draft Pick', '300+ HR Career Batting']
# ['Arizona Diamondbacks', 'Seattle Mariners']
# ['Arizona Diamondbacks', 'Played Right Field min. 1 game']
# ['Arizona Diamondbacks', '30+ SB Season']
# ['Houston Astros', 'Seattle Mariners']
# ['Houston Astros', 'Played Right Field min. 1 game']
# ['Houston Astros', '30+ SB Season']
# ['100+ Run Season Batting', 'Seattle Mariners']
# ['100+ Run Season Batting', 'Played Right Field min. 1 game']
# ['100+ Run Season Batting', '30+ SB Season']
# ['St. Louis Cardinals', 'Toronto Blue Jays']
# ['St. Louis Cardinals', '6+ WAR Season']
# ['St. Louis Cardinals', 'Played First Base min. 1 game']
# ['Philadelphia Phillies', 'Toronto Blue Jays']
# ['Philadelphia Phillies', '6+ WAR Season']
# ['Philadelphia Phillies', 'Played First Base min. 1 game']
# ['Washington Nationals', 'Toronto Blue Jays']
# ['Washington Nationals', '6+ WAR Season']
# ['Washington Nationals', 'Played First Base min. 1 game']
# ['Cleveland Guardians', 'San Diego Padres']
# ['Cleveland Guardians', 'Los Angeles Dodgers']
# ['Cleveland Guardians', 'Gold Glove']
# ['Chicago Cubs', 'San Diego Padres']
# ['Chicago Cubs', 'Los Angeles Dodgers']
# ['Chicago Cubs', 'Gold Glove']
# ['30+ HR Season Batting', 'San Diego Padres']
# ['30+ HR Season Batting', 'Los Angeles Dodgers']
# ['30+ HR Season Batting', 'Gold Glove']
# ['Texas Rangers', 'Baltimore Orioles']
# ['Texas Rangers', 'Detroit Tigers']
# ['Texas Rangers', '200+ K Season Pitching']
# ['Atlanta Braves', 'Baltimore Orioles']
# ['Atlanta Braves', 'Detroit Tigers']
# ['Atlanta Braves', '200+ K Season Pitching']
# ['Boston Red Sox', 'Baltimore Orioles']
# ['Boston Red Sox', 'Detroit Tigers']
# ['Boston Red Sox', '200+ K Season Pitching']
# ['Chicago White Sox', 'Kansas City Royals']
# ['Chicago White Sox', 'Minnesota Twins']
# ['Chicago White Sox', 'Born Outside US 50 States and DC']
# ['Colorado Rockies', 'Kansas City Royals']
# ['Colorado Rockies', 'Minnesota Twins']
# ['Colorado Rockies', 'Born Outside US 50 States and DC']
# ['Played Shortstop min. 1 game', 'Kansas City Royals']
# ['Played Shortstop min. 1 game', 'Minnesota Twins']
# ['Played Shortstop min. 1 game', 'Born Outside US 50 States and DC']
# ['Pitched min. 1 game', 'All Star']
# ['Pitched min. 1 game', 'MVP']
# ['Pitched min. 1 game', 'Only One Team']
# ['.300+ AVG Career Batting', 'All Star']
# ['.300+ AVG Career Batting', 'MVP']
# ['.300+ AVG Career Batting', 'Only One Team']
# ['20+ Win Season Pitching', 'All Star']
# ['20+ Win Season Pitching', 'MVP']
# ['20+ Win Season Pitching', 'Only One Team']
# ['New York Mets', 'San Francisco Giants']
# ['New York Mets', '200+ Wins Career Pitching']
# ['New York Mets', 'Played Second Base min. 1 game']
# ['Los Angeles Angels', 'San Francisco Giants']
# ['Los Angeles Angels', '200+ Wins Career Pitching']
# ['Los Angeles Angels', 'Played Second Base min. 1 game']
# ['Oakland Athletics', 'San Francisco Giants']
# ['Oakland Athletics', '200+ Wins Career Pitching']
# ['Oakland Athletics', 'Played Second Base min. 1 game']
# ['Houston Astros', 'New York Yankees']
# ['Houston Astros', 'Played Outfield min. 1 game']
# ['Houston Astros', 'Played Catcher min. 1 game']
# ['Cincinnati Reds', 'New York Yankees']
# ['Cincinnati Reds', 'Played Outfield min. 1 game']
# ['Cincinnati Reds', 'Played Catcher min. 1 game']
# ['San Diego Padres', 'New York Yankees']
# ['San Diego Padres', 'Played Outfield min. 1 game']
# ['San Diego Padres', 'Played Catcher min. 1 game']
# ['Philadelphia Phillies', 'Baltimore Orioles']
# ['Philadelphia Phillies', 'Pittsburgh Pirates']
# ['Philadelphia Phillies', '≤ 3.00 ERA Season']
# ['Toronto Blue Jays', 'Baltimore Orioles']
# ['Toronto Blue Jays', 'Pittsburgh Pirates']
# ['Toronto Blue Jays', '≤ 3.00 ERA Season']
# ['Hall of Fame', 'Baltimore Orioles']
# ['Hall of Fame', 'Pittsburgh Pirates']
# ['Hall of Fame', '≤ 3.00 ERA Season']
# ['Seattle Mariners', 'Tampa Bay Rays']
# ['Seattle Mariners', '40+ WAR Career']
# ['Seattle Mariners', '.300+ AVG Season Batting']
# ['Washington Nationals', 'Tampa Bay Rays']
# ['Washington Nationals', '40+ WAR Career']
# ['Washington Nationals', '.300+ AVG Season Batting']
# ['St. Louis Cardinals', 'Tampa Bay Rays']
# ['St. Louis Cardinals', '40+ WAR Career']
# ['St. Louis Cardinals', '.300+ AVG Season Batting']
# ['Detroit Tigers', 'Minnesota Twins']
# ['Detroit Tigers', '2000+ Hits Career Batting']
# ['Detroit Tigers', '40+ HR Season Batting']
# ['Boston Red Sox', 'Minnesota Twins']
# ['Boston Red Sox', '2000+ Hits Career Batting']
# ['Boston Red Sox', '40+ HR Season Batting']
# ['Milwaukee Brewers', 'Minnesota Twins']
# ['Milwaukee Brewers', '2000+ Hits Career Batting']
# ['Milwaukee Brewers', '40+ HR Season Batting']
# ['Los Angeles Dodgers', 'Cincinnati Reds']
# ['Los Angeles Dodgers', 'Played Shortstop min. 1 game']
# ['Los Angeles Dodgers', '6+ WAR Season']
# ['Texas Rangers', 'Cincinnati Reds']
# ['Texas Rangers', 'Played Shortstop min. 1 game']
# ['Texas Rangers', '6+ WAR Season']
# ['Atlanta Braves', 'Cincinnati Reds']
# ['Atlanta Braves', 'Played Shortstop min. 1 game']
# ['Atlanta Braves', '6+ WAR Season']
# ['Chicago Cubs', '30+ SB Season']
# ['Chicago Cubs', '100+ RBI Season Batting']
# ['Chicago Cubs', '200+ Hits Season Batting']
# ['San Francisco Giants', '30+ SB Season']
# ['San Francisco Giants', '100+ RBI Season Batting']
# ['San Francisco Giants', '200+ Hits Season Batting']
# ['Born Outside US 50 States and DC', '30+ SB Season']
# ['Born Outside US 50 States and DC', '100+ RBI Season Batting']
# ['Born Outside US 50 States and DC', '200+ Hits Season Batting']
# ['Baltimore Orioles', 'Oakland Athletics']
# ['Baltimore Orioles', '300+ HR Career Batting']
# ['Baltimore Orioles', 'All Star']
# ['Cleveland Guardians', 'Oakland Athletics']
# ['Cleveland Guardians', '300+ HR Career Batting']
# ['Cleveland Guardians', 'All Star']
# ['Silver Slugger', 'Oakland Athletics']
# ['Silver Slugger', '300+ HR Career Batting']
# ['Silver Slugger', 'All Star']
# ['Minnesota Twins', 'Played First Base min. 1 game']
# ['Minnesota Twins', 'Played Second Base min. 1 game']
# ['Minnesota Twins', 'Played Third Base min. 1 game']
# ['Arizona Diamondbacks', 'Played First Base min. 1 game']
# ['Arizona Diamondbacks', 'Played Second Base min. 1 game']
# ['Arizona Diamondbacks', 'Played Third Base min. 1 game']
# ['Chicago White Sox', 'Played First Base min. 1 game']
# ['Chicago White Sox', 'Played Second Base min. 1 game']
# ['Chicago White Sox', 'Played Third Base min. 1 game']
# ['Detroit Tigers', 'Miami Marlins']
# ['Detroit Tigers', 'St. Louis Cardinals']
# ['Detroit Tigers', 'Hall of Fame']
# ['New York Yankees', 'Miami Marlins']
# ['New York Yankees', 'St. Louis Cardinals']
# ['New York Yankees', 'Hall of Fame']
# ['Milwaukee Brewers', 'Miami Marlins']
# ['Milwaukee Brewers', 'St. Louis Cardinals']
# ['Milwaukee Brewers', 'Hall of Fame']
# ['Kansas City Royals', 'Boston Red Sox']
# ['Kansas City Royals', 'Cincinnati Reds']
# ['Kansas City Royals', 'Los Angeles Angels']
# ['Seattle Mariners', 'Boston Red Sox']
# ['Seattle Mariners', 'Cincinnati Reds']
# ['Seattle Mariners', 'Los Angeles Angels']
# ['300+ Save Career Pitching', 'Boston Red Sox']
# ['300+ Save Career Pitching', 'Cincinnati Reds']
# ['300+ Save Career Pitching', 'Los Angeles Angels']
# ['Philadelphia Phillies', 'San Diego Padres']
# ['Philadelphia Phillies', 'Houston Astros']
# ['Philadelphia Phillies', '20+ Win Season Pitching']
# ['New York Mets', 'San Diego Padres']
# ['New York Mets', 'Houston Astros']
# ['New York Mets', '20+ Win Season Pitching']
# ['≤ 3.00 ERA Season', 'San Diego Padres']
# ['≤ 3.00 ERA Season', 'Houston Astros']
# ['≤ 3.00 ERA Season', '20+ Win Season Pitching']
# ['Chicago Cubs', 'Atlanta Braves']
# ['Chicago Cubs', 'San Francisco Giants']
# ['Chicago Cubs', 'Played Catcher min. 1 game']
# ['Toronto Blue Jays', 'Atlanta Braves']
# ['Toronto Blue Jays', 'San Francisco Giants']
# ['Toronto Blue Jays', 'Played Catcher min. 1 game']
# ['Pittsburgh Pirates', 'Atlanta Braves']
# ['Pittsburgh Pirates', 'San Francisco Giants']
# ['Pittsburgh Pirates', 'Played Catcher min. 1 game']
# ['40+ HR Season Batting', 'Played Left Field min. 1 game']
# ['40+ HR Season Batting', 'Played Center Field min. 1 game']
# ['40+ HR Season Batting', 'Played Right Field min. 1 game']
# ['Only One Team', 'Played Left Field min. 1 game']
# ['Only One Team', 'Played Center Field min. 1 game']
# ['Only One Team', 'Played Right Field min. 1 game']
# ['3000+ Hits Career Batting', 'Played Left Field min. 1 game']
# ['3000+ Hits Career Batting', 'Played Center Field min. 1 game']
# ['3000+ Hits Career Batting', 'Played Right Field min. 1 game']
# ['Oakland Athletics', 'Texas Rangers']
# ['Oakland Athletics', '200+ K Season Pitching']
# ['Oakland Athletics', 'First Round Draft Pick']
# ['Seattle Mariners', 'Texas Rangers']
# ['Seattle Mariners', '200+ K Season Pitching']
# ['Seattle Mariners', 'First Round Draft Pick']
# ['Los Angeles Angels', 'Texas Rangers']
# ['Los Angeles Angels', '200+ K Season Pitching']
# ['Los Angeles Angels', 'First Round Draft Pick']
# ['Baltimore Orioles', 'Washington Nationals']
# ['Baltimore Orioles', '2000+ K Career Pitching']
# ['Baltimore Orioles', 'Threw a No-Hitter']
# ['Chicago White Sox', 'Washington Nationals']
# ['Chicago White Sox', '2000+ K Career Pitching']
# ['Chicago White Sox', 'Threw a No-Hitter']
# ['All Star', 'Washington Nationals']
# ['All Star', '2000+ K Career Pitching']
# ['All Star', 'Threw a No-Hitter']
# ['Los Angeles Dodgers', 'Boston Red Sox']
# ['Los Angeles Dodgers', 'Rookie of the Year']
# ['Los Angeles Dodgers', '300+ HR Career Batting']
# ['MVP', 'Boston Red Sox']
# ['MVP', 'Rookie of the Year']
# ['MVP', '300+ HR Career Batting']
# ['Gold Glove', 'Boston Red Sox']
# ['Gold Glove', 'Rookie of the Year']
# ['Gold Glove', '300+ HR Career Batting']
# ['New York Yankees', 'Cleveland Guardians']
# ['New York Yankees', 'Colorado Rockies']
# ['New York Yankees', '200+ Hits Season Batting']
# ['Detroit Tigers', 'Cleveland Guardians']
# ['Detroit Tigers', 'Colorado Rockies']
# ['Detroit Tigers', '200+ Hits Season Batting']
# ['St. Louis Cardinals', 'Cleveland Guardians']
# ['St. Louis Cardinals', 'Colorado Rockies']
# ['St. Louis Cardinals', '200+ Hits Season Batting']
# ['Minnesota Twins', 'Chicago Cubs']
# ['Minnesota Twins', '.300+ AVG Career Batting']
# ['Minnesota Twins', '200+ Wins Career Pitching']
# ['Pittsburgh Pirates', 'Chicago Cubs']
# ['Pittsburgh Pirates', '.300+ AVG Career Batting']
# ['Pittsburgh Pirates', '200+ Wins Career Pitching']
# ['Cincinnati Reds', 'Chicago Cubs']
# ['Cincinnati Reds', '.300+ AVG Career Batting']
# ['Cincinnati Reds', '200+ Wins Career Pitching']
# ['Kansas City Royals', 'Baltimore Orioles']
# ['Kansas City Royals', '6+ WAR Season']
# ['Kansas City Royals', '10+ Win Season Pitching']
# ['Houston Astros', 'Baltimore Orioles']
# ['Houston Astros', '6+ WAR Season']
# ['Houston Astros', '10+ Win Season Pitching']
# ['≤ 3.00 ERA Season', 'Baltimore Orioles']
# ['≤ 3.00 ERA Season', '6+ WAR Season']
# ['≤ 3.00 ERA Season', '10+ Win Season Pitching']
# ['100+ Run Season Batting', '.300+ AVG Season Batting']
# ['100+ Run Season Batting', '30+ HR Season Batting']
# ['100+ Run Season Batting', 'Played Second Base min. 1 game']
# ['100+ RBI Season Batting', '.300+ AVG Season Batting']
# ['100+ RBI Season Batting', '30+ HR Season Batting']
# ['100+ RBI Season Batting', 'Played Second Base min. 1 game']
# ['30+ SB Season', '.300+ AVG Season Batting']
# ['30+ SB Season', '30+ HR Season Batting']
# ['30+ SB Season', 'Played Second Base min. 1 game']
# ['New York Mets', 'Milwaukee Brewers']
# ['New York Mets', 'Philadelphia Phillies']
# ['New York Mets', 'Hall of Fame']
# ['Boston Red Sox', 'Milwaukee Brewers']
# ['Boston Red Sox', 'Philadelphia Phillies']
# ['Boston Red Sox', 'Hall of Fame']
# ['Only One Team', 'Milwaukee Brewers']
# ['Only One Team', 'Philadelphia Phillies']
# ['Only One Team', 'Hall of Fame']
# ['San Diego Padres', 'Tampa Bay Rays']
# ['San Diego Padres', 'Played Shortstop min. 1 game']
# ['San Diego Padres', 'Born Outside US 50 States and DC']
# ['Toronto Blue Jays', 'Tampa Bay Rays']
# ['Toronto Blue Jays', 'Played Shortstop min. 1 game']
# ['Toronto Blue Jays', 'Born Outside US 50 States and DC']
# ['2000+ Hits Career Batting', 'Tampa Bay Rays']
# ['2000+ Hits Career Batting', 'Played Shortstop min. 1 game']
# ['2000+ Hits Career Batting', 'Born Outside US 50 States and DC']
# ['Seattle Mariners', 'San Francisco Giants']
# ['Seattle Mariners', 'Pitched min. 1 game']
# ['Seattle Mariners', 'Played Catcher min. 1 game']
# ['Atlanta Braves', 'San Francisco Giants']
# ['Atlanta Braves', 'Pitched min. 1 game']
# ['Atlanta Braves', 'Played Catcher min. 1 game']
# ['Washington Nationals', 'San Francisco Giants']
# ['Washington Nationals', 'Pitched min. 1 game']
# ['Washington Nationals', 'Played Catcher min. 1 game']
# ['Los Angeles Dodgers', 'Chicago White Sox']
# ['Los Angeles Dodgers', 'Gold Glove']
# ['Los Angeles Dodgers', 'MVP']
# ['St. Louis Cardinals', 'Chicago White Sox']
# ['St. Louis Cardinals', 'Gold Glove']
# ['St. Louis Cardinals', 'MVP']
# ['Texas Rangers', 'Chicago White Sox']
# ['Texas Rangers', 'Gold Glove']
# ['Texas Rangers', 'MVP']
# ['Kansas City Royals', 'Pittsburgh Pirates']
# ['Kansas City Royals', 'Played Outfield min. 1 game']
# ['Kansas City Royals', '300+ HR Career Batting']
# ['Miami Marlins', 'Pittsburgh Pirates']
# ['Miami Marlins', 'Played Outfield min. 1 game']
# ['Miami Marlins', '300+ HR Career Batting']
# ['Oakland Athletics', 'Pittsburgh Pirates']
# ['Oakland Athletics', 'Played Outfield min. 1 game']
# ['Oakland Athletics', '300+ HR Career Batting']
# ['Los Angeles Angels', 'Arizona Diamondbacks']
# ['Los Angeles Angels', '40+ WAR Career']
# ['Los Angeles Angels', 'Played First Base min. 1 game']
# ['Detroit Tigers', 'Arizona Diamondbacks']
# ['Detroit Tigers', '40+ WAR Career']
# ['Detroit Tigers', 'Played First Base min. 1 game']
# ['First Round Draft Pick', 'Arizona Diamondbacks']
# ['First Round Draft Pick', '40+ WAR Career']
# ['First Round Draft Pick', 'Played First Base min. 1 game']
# ['New York Yankees', '200+ Wins Career Pitching']
# ['New York Yankees', 'Silver Slugger']
# ['New York Yankees', '6+ WAR Season']
# ['Cleveland Guardians', '200+ Wins Career Pitching']
# ['Cleveland Guardians', 'Silver Slugger']
# ['Cleveland Guardians', '6+ WAR Season']
# ['Cy Young', '200+ Wins Career Pitching']
# ['Cy Young', 'Silver Slugger']
# ['Cy Young', '6+ WAR Season']
# ['Philadelphia Phillies', 'Chicago Cubs']
# ['Philadelphia Phillies', 'Played Third Base min. 1 game']
# ['Philadelphia Phillies', '30+ HR Season Batting']
# ['Los Angeles Angels', 'Chicago Cubs']
# ['Los Angeles Angels', 'Played Third Base min. 1 game']
# ['Los Angeles Angels', '30+ HR Season Batting']
# ['Houston Astros', 'Chicago Cubs']
# ['Houston Astros', 'Played Third Base min. 1 game']
# ['Houston Astros', '30+ HR Season Batting']
# ['Boston Red Sox', 'Atlanta Braves']
# ['Boston Red Sox', 'Played Center Field min. 1 game']
# ['Boston Red Sox', 'United States']
# ['Chicago White Sox', 'Atlanta Braves']
# ['Chicago White Sox', 'Played Center Field min. 1 game']
# ['Chicago White Sox', 'United States']
# ['200+ Hits Season Batting', 'Atlanta Braves']
# ['200+ Hits Season Batting', 'Played Center Field min. 1 game']
# ['200+ Hits Season Batting', 'United States']
# ['Washington Nationals', 'Oakland Athletics']
# ['Washington Nationals', 'Cincinnati Reds']
# ['Washington Nationals', '100+ RBI Season Batting']
# ['Minnesota Twins', 'Oakland Athletics']
# ['Minnesota Twins', 'Cincinnati Reds']
# ['Minnesota Twins', '100+ RBI Season Batting']
# ['Rookie of the Year', 'Oakland Athletics']
# ['Rookie of the Year', 'Cincinnati Reds']
# ['Rookie of the Year', '100+ RBI Season Batting']
# ['San Francisco Giants', 'Colorado Rockies']
# ['San Francisco Giants', 'Baltimore Orioles']
# ['San Francisco Giants', 'Played Left Field min. 1 game']
# ['New York Mets', 'Colorado Rockies']
# ['New York Mets', 'Baltimore Orioles']
# ['New York Mets', 'Played Left Field min. 1 game']
# ['Played Right Field min. 1 game', 'Colorado Rockies']
# ['Played Right Field min. 1 game', 'Baltimore Orioles']
# ['Played Right Field min. 1 game', 'Played Left Field min. 1 game']
# ['Toronto Blue Jays', '10+ HR Season Batting']
# ['Toronto Blue Jays', '10+ Win Season Pitching']
# ['Toronto Blue Jays', 'All Star']
# ['Born Outside US 50 States and DC', '10+ HR Season Batting']
# ['Born Outside US 50 States and DC', '10+ Win Season Pitching']
# ['Born Outside US 50 States and DC', 'All Star']
# ['Canada', '10+ HR Season Batting']
# ['Canada', '10+ Win Season Pitching']
# ['Canada', 'All Star']
# ['Milwaukee Brewers', 'Kansas City Royals']
# ['Milwaukee Brewers', '≤ 3.00 ERA Season']
# ['Milwaukee Brewers', '.300+ AVG Season Batting']
# ['Chicago Cubs', 'Kansas City Royals']
# ['Chicago Cubs', '≤ 3.00 ERA Season']
# ['Chicago Cubs', '.300+ AVG Season Batting']
# ['New York Yankees', 'Kansas City Royals']
# ['New York Yankees', '≤ 3.00 ERA Season']
# ['New York Yankees', '.300+ AVG Season Batting']
# ['Houston Astros', 'Hall of Fame']
# ['Houston Astros', 'All Star']
# ['Houston Astros', 'Only One Team']
# ['Texas Rangers', 'Hall of Fame']
# ['Texas Rangers', 'All Star']
# ['Texas Rangers', 'Only One Team']
# ['2000+ Hits Career Batting', 'Hall of Fame']
# ['2000+ Hits Career Batting', 'All Star']
# ['2000+ Hits Career Batting', 'Only One Team']
# ['Boston Red Sox', 'Cleveland Guardians']
# ['Boston Red Sox', 'New York Mets']
# ['Boston Red Sox', 'Pitched min. 1 game']
# ['Minnesota Twins', 'Cleveland Guardians']
# ['Minnesota Twins', 'New York Mets']
# ['Minnesota Twins', 'Pitched min. 1 game']
# ['Played Catcher min. 1 game', 'Cleveland Guardians']
# ['Played Catcher min. 1 game', 'New York Mets']
# ['Played Catcher min. 1 game', 'Pitched min. 1 game']
# ['Baltimore Orioles', 'San Diego Padres']
# ['Baltimore Orioles', 'Played Shortstop min. 1 game']
# ['Baltimore Orioles', 'Silver Slugger']
# ['Pittsburgh Pirates', 'San Diego Padres']
# ['Pittsburgh Pirates', 'Played Shortstop min. 1 game']
# ['Pittsburgh Pirates', 'Silver Slugger']
# ['San Francisco Giants', 'San Diego Padres']
# ['San Francisco Giants', 'Played Shortstop min. 1 game']
# ['San Francisco Giants', 'Silver Slugger']
# ['Cincinnati Reds', 'St. Louis Cardinals']
# ['Cincinnati Reds', 'Chicago White Sox']
# ['Cincinnati Reds', 'Gold Glove']
# ['Seattle Mariners', 'St. Louis Cardinals']
# ['Seattle Mariners', 'Chicago White Sox']
# ['Seattle Mariners', 'Gold Glove']
# ['Philadelphia Phillies', 'St. Louis Cardinals']
# ['Philadelphia Phillies', 'Chicago White Sox']
# ['Philadelphia Phillies', 'Gold Glove']
# ['Los Angeles Angels', 'Los Angeles Dodgers']
# ['Los Angeles Angels', '2000+ K Career Pitching']
# ['Los Angeles Angels', '10+ Win Season Pitching']
# ['Atlanta Braves', 'Los Angeles Dodgers']
# ['Atlanta Braves', '2000+ K Career Pitching']
# ['Atlanta Braves', '10+ Win Season Pitching']
# ['Detroit Tigers', 'Los Angeles Dodgers']
# ['Detroit Tigers', '2000+ K Career Pitching']
# ['Detroit Tigers', '10+ Win Season Pitching']
# ['Oakland Athletics', 'Toronto Blue Jays']
# ['Oakland Athletics', 'Boston Red Sox']
# ['Oakland Athletics', '30+ SB Season']
# ['New York Yankees', 'Toronto Blue Jays']
# ['New York Yankees', 'Boston Red Sox']
# ['New York Yankees', '30+ SB Season']
# ['San Diego Padres', 'Toronto Blue Jays']
# ['San Diego Padres', 'Boston Red Sox']
# ['San Diego Padres', '30+ SB Season']
# ['New York Mets', 'Tampa Bay Rays']
# ['New York Mets', 'Kansas City Royals']
# ['New York Mets', '40+ WAR Career']
# ['Minnesota Twins', 'Tampa Bay Rays']
# ['Minnesota Twins', 'Kansas City Royals']
# ['Minnesota Twins', '40+ WAR Career']
# ['Played Second Base min. 1 game', 'Tampa Bay Rays']
# ['Played Second Base min. 1 game', 'Kansas City Royals']
# ['Played Second Base min. 1 game', '40+ WAR Career']
# ['.300+ AVG Season Batting', 'Played Outfield min. 1 game']
# ['.300+ AVG Season Batting', '3000+ Hits Career Batting']
# ['.300+ AVG Season Batting', '30+ HR Season Batting']
# ['First Round Draft Pick', 'Played Outfield min. 1 game']
# ['First Round Draft Pick', '3000+ Hits Career Batting']
# ['First Round Draft Pick', '30+ HR Season Batting']
# ['MVP', 'Played Outfield min. 1 game']
# ['MVP', '3000+ Hits Career Batting']
# ['MVP', '30+ HR Season Batting']
# ['Chicago White Sox', 'Cleveland Guardians']
# ['Chicago White Sox', 'Detroit Tigers']
# ['Chicago White Sox', '300+ HR Career Batting']
# ['Chicago Cubs', 'Cleveland Guardians']
# ['Chicago Cubs', 'Detroit Tigers']
# ['Chicago Cubs', '300+ HR Career Batting']
# ['Washington Nationals', 'Cleveland Guardians']
# ['Washington Nationals', 'Detroit Tigers']
# ['Washington Nationals', '300+ HR Career Batting']
# ['St. Louis Cardinals', 'Played Catcher min. 1 game']
# ['St. Louis Cardinals', 'All Star']
# ['St. Louis Cardinals', 'Hall of Fame']
# ['San Francisco Giants', 'Played Catcher min. 1 game']
# ['San Francisco Giants', 'All Star']
# ['San Francisco Giants', 'Hall of Fame']
# ['Played In Major Negro Lgs', 'Played Catcher min. 1 game']
# ['Played In Major Negro Lgs', 'All Star']
# ['Played In Major Negro Lgs', 'Hall of Fame']
# ['Seattle Mariners', 'Philadelphia Phillies']
# ['Seattle Mariners', 'Played Third Base min. 1 game']
# ['Seattle Mariners', '100+ RBI Season Batting']
# ['New York Yankees', 'Philadelphia Phillies']
# ['New York Yankees', 'Played Third Base min. 1 game']
# ['New York Yankees', '100+ RBI Season Batting']
# ['Texas Rangers', 'Philadelphia Phillies']
# ['Texas Rangers', 'Played Third Base min. 1 game']
# ['Texas Rangers', '100+ RBI Season Batting']
# ['Boston Red Sox', 'Pittsburgh Pirates']
# ['Boston Red Sox', '30+ Save Season Pitching']
# ['Boston Red Sox', 'Silver Slugger']
# ['Cincinnati Reds', 'Pittsburgh Pirates']
# ['Cincinnati Reds', '30+ Save Season Pitching']
# ['Cincinnati Reds', 'Silver Slugger']
# ['Minnesota Twins', 'Pittsburgh Pirates']
# ['Minnesota Twins', '30+ Save Season Pitching']
# ['Minnesota Twins', 'Silver Slugger']
# ['San Diego Padres', 'Oakland Athletics']
# ['San Diego Padres', 'Houston Astros']
# ['San Diego Padres', '200+ K Season Pitching']
# ['Milwaukee Brewers', 'Oakland Athletics']
# ['Milwaukee Brewers', 'Houston Astros']
# ['Milwaukee Brewers', '200+ K Season Pitching']
# ['San Francisco Giants', 'Oakland Athletics']
# ['San Francisco Giants', 'Houston Astros']
# ['San Francisco Giants', '200+ K Season Pitching']
# ['Cleveland Guardians', '10+ Win Season Pitching']
# ['Cleveland Guardians', 'Played Shortstop min. 1 game']
# ['Cleveland Guardians', 'Born Outside US 50 States and DC']
# ['Washington Nationals', '10+ Win Season Pitching']
# ['Washington Nationals', 'Played Shortstop min. 1 game']
# ['Washington Nationals', 'Born Outside US 50 States and DC']
# ['Miami Marlins', '10+ Win Season Pitching']
# ['Miami Marlins', 'Played Shortstop min. 1 game']
# ['Miami Marlins', 'Born Outside US 50 States and DC']
# ['Detroit Tigers', 'Toronto Blue Jays']
# ['Detroit Tigers', '6+ WAR Season']
# ['Detroit Tigers', 'Only One Team']
# ['200+ Wins Career Pitching', 'Toronto Blue Jays']
# ['200+ Wins Career Pitching', '6+ WAR Season']
# ['200+ Wins Career Pitching', 'Only One Team']
# ['Played First Base min. 1 game', 'Toronto Blue Jays']
# ['Played First Base min. 1 game', '6+ WAR Season']
# ['Played First Base min. 1 game', 'Only One Team']
# ['New York Mets', 'Chicago Cubs']
# ['New York Mets', '2000+ Hits Career Batting']
# ['New York Mets', 'Pitched min. 1 game']
# ['Los Angeles Dodgers', 'Chicago Cubs']
# ['Los Angeles Dodgers', '2000+ Hits Career Batting']
# ['Los Angeles Dodgers', 'Pitched min. 1 game']
# ['Baltimore Orioles', 'Chicago Cubs']
# ['Baltimore Orioles', '2000+ Hits Career Batting']
# ['Baltimore Orioles', 'Pitched min. 1 game']
# ['New York Yankees', 'Atlanta Braves']
# ['New York Yankees', '100+ Run Season Batting']
# ['New York Yankees', 'All Star']
# ['Oakland Athletics', 'Atlanta Braves']
# ['Oakland Athletics', '100+ Run Season Batting']
# ['Oakland Athletics', 'All Star']
# ['Colorado Rockies', 'Atlanta Braves']
# ['Colorado Rockies', '100+ Run Season Batting']
# ['Colorado Rockies', 'All Star']
# ['Los Angeles Angels', 'Chicago White Sox']
# ['Los Angeles Angels', 'Philadelphia Phillies']
# ['Los Angeles Angels', '.300+ AVG Season Batting']
# ['Minnesota Twins', 'Chicago White Sox']
# ['Minnesota Twins', 'Philadelphia Phillies']
# ['Minnesota Twins', '.300+ AVG Season Batting']
# ['Hall of Fame', 'Chicago White Sox']
# ['Hall of Fame', 'Philadelphia Phillies']
# ['Hall of Fame', '.300+ AVG Season Batting']
# ['Detroit Tigers', 'Cincinnati Reds']
# ['Detroit Tigers', 'Kansas City Royals']
# ['Detroit Tigers', '300+ HR Career Batting']
# ['Arizona Diamondbacks', 'Cincinnati Reds']
# ['Arizona Diamondbacks', 'Kansas City Royals']
# ['Arizona Diamondbacks', '300+ HR Career Batting']
# ['Played Catcher min. 1 game', 'Cincinnati Reds']
# ['Played Catcher min. 1 game', 'Kansas City Royals']
# ['Played Catcher min. 1 game', '300+ HR Career Batting']
# ['Washington Nationals', 'San Diego Padres']
# ['Washington Nationals', 'New York Mets']
# ['Washington Nationals', 'Played Third Base min. 1 game']
# ['St. Louis Cardinals', 'San Diego Padres']
# ['St. Louis Cardinals', 'New York Mets']
# ['St. Louis Cardinals', 'Played Third Base min. 1 game']
# ['100+ RBI Season Batting', 'San Diego Padres']
# ['100+ RBI Season Batting', 'New York Mets']
# ['100+ RBI Season Batting', 'Played Third Base min. 1 game']
# ['Seattle Mariners', 'Los Angeles Dodgers']
# ['Seattle Mariners', 'Played Center Field min. 1 game']
# ['Seattle Mariners', '30+ HR Season Batting']
# ['Milwaukee Brewers', 'Los Angeles Dodgers']
# ['Milwaukee Brewers', 'Played Center Field min. 1 game']
# ['Milwaukee Brewers', '30+ HR Season Batting']
# ['Texas Rangers', 'Los Angeles Dodgers']
# ['Texas Rangers', 'Played Center Field min. 1 game']
# ['Texas Rangers', '30+ HR Season Batting']
# ['2000+ K Career Pitching', '200+ K Season Pitching']
# ['2000+ K Career Pitching', '40+ WAR Career']
# ['2000+ K Career Pitching', '200+ Wins Career Pitching']
# ['MVP', '200+ K Season Pitching']
# ['MVP', '40+ WAR Career']
# ['MVP', '200+ Wins Career Pitching']
# ['Threw a No-Hitter', '200+ K Season Pitching']
# ['Threw a No-Hitter', '40+ WAR Career']
# ['Threw a No-Hitter', '200+ Wins Career Pitching']
# ['Pittsburgh Pirates', 'Houston Astros']
# ['Pittsburgh Pirates', '20+ Win Season Pitching']
# ['Pittsburgh Pirates', '30+ SB Season']
# ['Boston Red Sox', 'Houston Astros']
# ['Boston Red Sox', '20+ Win Season Pitching']
# ['Boston Red Sox', '30+ SB Season']
# ['Atlanta Braves', 'Houston Astros']
# ['Atlanta Braves', '20+ Win Season Pitching']
# ['Atlanta Braves', '30+ SB Season']
# ['Chicago White Sox', 'All Star']
# ['Chicago White Sox', 'Played Shortstop min. 1 game']
# ['Chicago White Sox', 'Played Outfield min. 1 game']
# ['Chicago Cubs', 'All Star']
# ['Chicago Cubs', 'Played Shortstop min. 1 game']
# ['Chicago Cubs', 'Played Outfield min. 1 game']
# ['Played In Major Negro Lgs', 'All Star']
# ['Played In Major Negro Lgs', 'Played Shortstop min. 1 game']
# ['Played In Major Negro Lgs', 'Played Outfield min. 1 game']
# ['New York Yankees', 'Los Angeles Angels']
# ['New York Yankees', 'Born Outside US 50 States and DC']
# ['New York Yankees', 'Only One Team']
# ['Oakland Athletics', 'Los Angeles Angels']
# ['Oakland Athletics', 'Born Outside US 50 States and DC']
# ['Oakland Athletics', 'Only One Team']
# ['100+ Run Season Batting', 'Los Angeles Angels']
# ['100+ Run Season Batting', 'Born Outside US 50 States and DC']
# ['100+ Run Season Batting', 'Only One Team']
# ['Baltimore Orioles', 'Los Angeles Dodgers']
# ['Baltimore Orioles', 'Played Catcher min. 1 game']
# ['Baltimore Orioles', 'First Round Draft Pick']
# ['Tampa Bay Rays', 'Los Angeles Dodgers']
# ['Tampa Bay Rays', 'Played Catcher min. 1 game']
# ['Tampa Bay Rays', 'First Round Draft Pick']
# ['Minnesota Twins', 'Los Angeles Dodgers']
# ['Minnesota Twins', 'Played Catcher min. 1 game']
# ['Minnesota Twins', 'First Round Draft Pick']
# ['Philadelphia Phillies', 'San Francisco Giants']
# ['Philadelphia Phillies', 'Cleveland Guardians']
# ['Philadelphia Phillies', '30+ Save Season Pitching']
# ['Toronto Blue Jays', 'San Francisco Giants']
# ['Toronto Blue Jays', 'Cleveland Guardians']
# ['Toronto Blue Jays', '30+ Save Season Pitching']
# ['≤ 3.00 ERA Season', 'San Francisco Giants']
# ['≤ 3.00 ERA Season', 'Cleveland Guardians']
# ['≤ 3.00 ERA Season', '30+ Save Season Pitching']
# ['All Star', 'Played Second Base min. 1 game']
# ['All Star', 'Played Right Field min. 1 game']
# ['All Star', 'Hall of Fame']
# ['Rookie of the Year', 'Played Second Base min. 1 game']
# ['Rookie of the Year', 'Played Right Field min. 1 game']
# ['Rookie of the Year', 'Hall of Fame']
# ['30+ HR Season Batting', 'Played Second Base min. 1 game']
# ['30+ HR Season Batting', 'Played Right Field min. 1 game']
# ['30+ HR Season Batting', 'Hall of Fame']
# ['100+ RBI Season Batting', '40+ WAR Career']
# ['100+ RBI Season Batting', '.300+ AVG Career Batting']
# ['100+ RBI Season Batting', '300+ HR Career Batting']
# ['200+ Hits Season Batting', '40+ WAR Career']
# ['200+ Hits Season Batting', '.300+ AVG Career Batting']
# ['200+ Hits Season Batting', '300+ HR Career Batting']
# ['Played Third Base min. 1 game', '40+ WAR Career']
# ['Played Third Base min. 1 game', '.300+ AVG Career Batting']
# ['Played Third Base min. 1 game', '300+ HR Career Batting']
# ['San Diego Padres', 'Gold Glove']
# ['San Diego Padres', '2000+ Hits Career Batting']
# ['San Diego Padres', 'Pitched min. 1 game']
# ['Kansas City Royals', 'Gold Glove']
# ['Kansas City Royals', '2000+ Hits Career Batting']
# ['Kansas City Royals', 'Pitched min. 1 game']
# ['Chicago Cubs', 'Gold Glove']
# ['Chicago Cubs', '2000+ Hits Career Batting']
# ['Chicago Cubs', 'Pitched min. 1 game']
# ['New York Mets', 'Detroit Tigers']
# ['New York Mets', 'Cincinnati Reds']
# ['New York Mets', '6+ WAR Season']
# ['Los Angeles Angels', 'Detroit Tigers']
# ['Los Angeles Angels', 'Cincinnati Reds']
# ['Los Angeles Angels', '6+ WAR Season']
# ['Played Shortstop min. 1 game', 'Detroit Tigers']
# ['Played Shortstop min. 1 game', 'Cincinnati Reds']
# ['Played Shortstop min. 1 game', '6+ WAR Season']
# ['Los Angeles Dodgers', 'Cy Young']
# ['Los Angeles Dodgers', '2000+ K Career Pitching']
# ['Los Angeles Dodgers', 'Played Left Field min. 1 game']
# ['Oakland Athletics', 'Cy Young']
# ['Oakland Athletics', '2000+ K Career Pitching']
# ['Oakland Athletics', 'Played Left Field min. 1 game']
# ['New York Yankees', 'Cy Young']
# ['New York Yankees', '2000+ K Career Pitching']
# ['New York Yankees', 'Played Left Field min. 1 game']
# ['Texas Rangers', '.300+ AVG Season Batting']
# ['Texas Rangers', '10+ Win Season Pitching']
# ['Texas Rangers', 'Born Outside US 50 States and DC']
# ['Philadelphia Phillies', '.300+ AVG Season Batting']
# ['Philadelphia Phillies', '10+ Win Season Pitching']
# ['Philadelphia Phillies', 'Born Outside US 50 States and DC']
# ['St. Louis Cardinals', '.300+ AVG Season Batting']
# ['St. Louis Cardinals', '10+ Win Season Pitching']
# ['St. Louis Cardinals', 'Born Outside US 50 States and DC']
# ['Atlanta Braves', 'Milwaukee Brewers']
# ['Atlanta Braves', 'Washington Nationals']
# ['Atlanta Braves', 'Played First Base min. 1 game']
# ['Boston Red Sox', 'Milwaukee Brewers']
# ['Boston Red Sox', 'Washington Nationals']
# ['Boston Red Sox', 'Played First Base min. 1 game']
# ['Silver Slugger', 'Milwaukee Brewers']
# ['Silver Slugger', 'Washington Nationals']
# ['Silver Slugger', 'Played First Base min. 1 game']
# ['Seattle Mariners', 'Cleveland Guardians']
# ['Seattle Mariners', 'Threw a No-Hitter']
# ['Seattle Mariners', 'Played Outfield min. 1 game']
# ['Pittsburgh Pirates', 'Cleveland Guardians']
# ['Pittsburgh Pirates', 'Threw a No-Hitter']
# ['Pittsburgh Pirates', 'Played Outfield min. 1 game']
# ['Houston Astros', 'Cleveland Guardians']
# ['Houston Astros', 'Threw a No-Hitter']
# ['Houston Astros', 'Played Outfield min. 1 game']
# ['Played Center Field min. 1 game', 'Hall of Fame']
# ['Played Center Field min. 1 game', 'San Francisco Giants']
# ['Played Center Field min. 1 game', '100+ Run Season Batting']
# ['Minnesota Twins', 'Hall of Fame']
# ['Minnesota Twins', 'San Francisco Giants']
# ['Minnesota Twins', '100+ Run Season Batting']
# ['40+ HR Season Batting', 'Hall of Fame']
# ['40+ HR Season Batting', 'San Francisco Giants']
# ['40+ HR Season Batting', '100+ Run Season Batting']
# ['Toronto Blue Jays', 'Chicago Cubs']
# ['Toronto Blue Jays', 'Played Right Field min. 1 game']
# ['Toronto Blue Jays', 'Only One Team']
# ['Chicago White Sox', 'Chicago Cubs']
# ['Chicago White Sox', 'Played Right Field min. 1 game']
# ['Chicago White Sox', 'Only One Team']
# ['MVP', 'Chicago Cubs']
# ['MVP', 'Played Right Field min. 1 game']
# ['MVP', 'Only One Team']
# ['Boston Red Sox', 'Colorado Rockies']
# ['Boston Red Sox', 'Played Second Base min. 1 game']
# ['Boston Red Sox', 'All Star']
# ['Cincinnati Reds', 'Colorado Rockies']
# ['Cincinnati Reds', 'Played Second Base min. 1 game']
# ['Cincinnati Reds', 'All Star']
# ['Los Angeles Angels', 'Colorado Rockies']
# ['Los Angeles Angels', 'Played Second Base min. 1 game']
# ['Los Angeles Angels', 'All Star']
# ['Cleveland Guardians', 'Baltimore Orioles']
# ['Cleveland Guardians', '30+ SB Season']
# ['Cleveland Guardians', '100+ RBI Season Batting']
# ['Arizona Diamondbacks', 'Baltimore Orioles']
# ['Arizona Diamondbacks', '30+ SB Season']
# ['Arizona Diamondbacks', '100+ RBI Season Batting']
# ['Detroit Tigers', 'Baltimore Orioles']
# ['Detroit Tigers', '30+ SB Season']
# ['Detroit Tigers', '100+ RBI Season Batting']
# ['Atlanta Braves', 'San Diego Padres']
# ['Atlanta Braves', '40+ WAR Career']
# ['Atlanta Braves', 'Played Third Base min. 1 game']
# ['Milwaukee Brewers', 'San Diego Padres']
# ['Milwaukee Brewers', '40+ WAR Career']
# ['Milwaukee Brewers', 'Played Third Base min. 1 game']
# ['Kansas City Royals', 'San Diego Padres']
# ['Kansas City Royals', '40+ WAR Career']
# ['Kansas City Royals', 'Played Third Base min. 1 game']
# ['Pittsburgh Pirates', 'New York Mets']
# ['Pittsburgh Pirates', 'New York Yankees']
# ['Pittsburgh Pirates', '300+ HR Career Batting']
# ['Texas Rangers', 'New York Mets']
# ['Texas Rangers', 'New York Yankees']
# ['Texas Rangers', '300+ HR Career Batting']
# ['.300+ AVG Career Batting', 'New York Mets']
# ['.300+ AVG Career Batting', 'New York Yankees']
# ['.300+ AVG Career Batting', '300+ HR Career Batting']
# ['St. Louis Cardinals', 'Oakland Athletics']
# ['St. Louis Cardinals', 'San Francisco Giants']
# ['St. Louis Cardinals', 'Washington Nationals']
# ['Los Angeles Dodgers', 'Oakland Athletics']
# ['Los Angeles Dodgers', 'San Francisco Giants']
# ['Los Angeles Dodgers', 'Washington Nationals']
# ['Seattle Mariners', 'Oakland Athletics']
# ['Seattle Mariners', 'San Francisco Giants']
# ['Seattle Mariners', 'Washington Nationals']
# ['2000+ K Career Pitching', 'Cy Young']
# ['2000+ K Career Pitching', 'Threw a No-Hitter']
# ['2000+ K Career Pitching', 'Born Outside US 50 States and DC']
# ['≤ 3.00 ERA Season', 'Cy Young']
# ['≤ 3.00 ERA Season', 'Threw a No-Hitter']
# ['≤ 3.00 ERA Season', 'Born Outside US 50 States and DC']
# ['Gold Glove', 'Cy Young']
# ['Gold Glove', 'Threw a No-Hitter']
# ['Gold Glove', 'Born Outside US 50 States and DC']
# ['Miami Marlins', 'Atlanta Braves']
# ['Miami Marlins', 'Philadelphia Phillies']
# ['Miami Marlins', 'Silver Slugger']
# ['Chicago Cubs', 'Atlanta Braves']
# ['Chicago Cubs', 'Philadelphia Phillies']
# ['Chicago Cubs', 'Silver Slugger']
# ['Played Right Field min. 1 game', 'Atlanta Braves']
# ['Played Right Field min. 1 game', 'Philadelphia Phillies']
# ['Played Right Field min. 1 game', 'Silver Slugger']
# ['Toronto Blue Jays', 'Chicago White Sox']
# ['Toronto Blue Jays', 'Houston Astros']
# ['Toronto Blue Jays', 'Played Center Field min. 1 game']
# ['Baltimore Orioles', 'Chicago White Sox']
# ['Baltimore Orioles', 'Houston Astros']
# ['Baltimore Orioles', 'Played Center Field min. 1 game']
# ['2000+ Hits Career Batting', 'Chicago White Sox']
# ['2000+ Hits Career Batting', 'Houston Astros']
# ['2000+ Hits Career Batting', 'Played Center Field min. 1 game']
# ['Boston Red Sox', 'Detroit Tigers']
# ['Boston Red Sox', '6+ WAR Season']
# ['Boston Red Sox', '10+ Win Season Pitching']
# ['Pittsburgh Pirates', 'Detroit Tigers']
# ['Pittsburgh Pirates', '6+ WAR Season']
# ['Pittsburgh Pirates', '10+ Win Season Pitching']
# ['Minnesota Twins', 'Detroit Tigers']
# ['Minnesota Twins', '6+ WAR Season']
# ['Minnesota Twins', '10+ Win Season Pitching']
# ['San Diego Padres', 'Tampa Bay Rays']
# ['San Diego Padres', 'Cincinnati Reds']
# ['San Diego Padres', 'Played Outfield min. 1 game']
# ['San Francisco Giants', 'Tampa Bay Rays']
# ['San Francisco Giants', 'Cincinnati Reds']
# ['San Francisco Giants', 'Played Outfield min. 1 game']
# ['New York Yankees', 'Tampa Bay Rays']
# ['New York Yankees', 'Cincinnati Reds']
# ['New York Yankees', 'Played Outfield min. 1 game']
# ['Cleveland Guardians', 'Los Angeles Angels']
# ['Cleveland Guardians', 'Los Angeles Dodgers']
# ['Cleveland Guardians', '30+ Save Season Pitching']
# ['New York Mets', 'Los Angeles Angels']
# ['New York Mets', 'Los Angeles Dodgers']
# ['New York Mets', '30+ Save Season Pitching']
# ['First Round Draft Pick', 'Los Angeles Angels']
# ['First Round Draft Pick', 'Los Angeles Dodgers']
# ['First Round Draft Pick', '30+ Save Season Pitching']
# ['Seattle Mariners', 'Milwaukee Brewers']
# ['Seattle Mariners', 'Played Left Field min. 1 game']
# ['Seattle Mariners', 'Hall of Fame']
# ['Baltimore Orioles', 'Milwaukee Brewers']
# ...
# ['Milwaukee Brewers', 'All Star']
# ['Milwaukee Brewers', 'MVP']
# ['Colorado Rockies', 'San Diego Padres']
# ['Colorado Rockies', 'All Star']
# ['Colorado Rockies', 'MVP']
# ['Minnesota Twins', 'San Diego Padres']
# ['Minnesota Twins', 'All Star']
# ['Minnesota Twins', 'MVP']
# ['Oakland Athletics', 'Seattle Mariners']
# ['Oakland Athletics', 'Silver Slugger']
# ['Oakland Athletics', 'Cy Young']
# ['Baltimore Orioles', 'Seattle Mariners']
# ['Baltimore Orioles', 'Silver Slugger']
# ['Baltimore Orioles', 'Cy Young']
# ['Houston Astros', 'Seattle Mariners']
# ['Houston Astros', 'Silver Slugger']
# ['Houston Astros', 'Cy Young']
# ['St. Louis Cardinals', 'Baltimore Orioles']
# ['St. Louis Cardinals', 'Gold Glove']
# ['St. Louis Cardinals', 'Rookie of the Year']
# ['Pittsburgh Pirates', 'Baltimore Orioles']
# ['Pittsburgh Pirates', 'Gold Glove']
# ['Pittsburgh Pirates', 'Rookie of the Year']
# ['Boston Red Sox', 'Baltimore Orioles']
# ['Boston Red Sox', 'Gold Glove']
# ['Boston Red Sox', 'Rookie of the Year']
# ['San Francisco Giants', 'Washington Nationals']
# ['San Francisco Giants', 'Gold Glove']
# ['San Francisco Giants', 'MVP']
# ['Detroit Tigers', 'Washington Nationals']
# ['Detroit Tigers', 'Gold Glove']
# ['Detroit Tigers', 'MVP']
# ['Pittsburgh Pirates', 'Washington Nationals']
# ['Pittsburgh Pirates', 'Gold Glove']
# ['Pittsburgh Pirates', 'MVP']
# ['Washington Nationals', 'Tampa Bay Rays']
# ['Washington Nationals', 'Silver Slugger']
# ['Washington Nationals', 'Rookie of the Year']
# ['Houston Astros', 'Tampa Bay Rays']
# ['Houston Astros', 'Silver Slugger']
# ['Houston Astros', 'Rookie of the Year']
# ['Boston Red Sox', 'Tampa Bay Rays']
# ['Boston Red Sox', 'Silver Slugger']
# ['Boston Red Sox', 'Rookie of the Year']
# ['Detroit Tigers', 'New York Yankees']
# ['Detroit Tigers', 'All Star']
# ['Detroit Tigers', 'Hall of Fame']
# ['Colorado Rockies', 'New York Yankees']
# ['Colorado Rockies', 'All Star']
# ['Colorado Rockies', 'Hall of Fame']
# ['Cleveland Guardians', 'New York Yankees']
# ['Cleveland Guardians', 'All Star']
# ['Cleveland Guardians', 'Hall of Fame']
# ['Houston Astros', 'San Diego Padres']
# ['Houston Astros', 'Rookie of the Year']
# ['Houston Astros', 'Silver Slugger']
# ['Tampa Bay Rays', 'San Diego Padres']
# ['Tampa Bay Rays', 'Rookie of the Year']
# ['Tampa Bay Rays', 'Silver Slugger']
# ['San Francisco Giants', 'San Diego Padres']
# ['San Francisco Giants', 'Rookie of the Year']
# ['San Francisco Giants', 'Silver Slugger']
# ['Detroit Tigers', 'Toronto Blue Jays']
# ['Detroit Tigers', 'All Star']
# ['Detroit Tigers', 'Gold Glove']
# ['Pittsburgh Pirates', 'Toronto Blue Jays']
# ['Pittsburgh Pirates', 'All Star']
# ['Pittsburgh Pirates', 'Gold Glove']
# ['Chicago Cubs', 'Toronto Blue Jays']
# ['Chicago Cubs', 'All Star']
# ['Chicago Cubs', 'Gold Glove']
# ['New York Yankees', 'Houston Astros']
# ['New York Yankees', 'MVP']
# ['New York Yankees', 'Rookie of the Year']
# ['San Francisco Giants', 'Houston Astros']
# ['San Francisco Giants', 'MVP']
# ['San Francisco Giants', 'Rookie of the Year']
# ['Oakland Athletics', 'Houston Astros']
# ['Oakland Athletics', 'MVP']
# ['Oakland Athletics', 'Rookie of the Year']
# ['Atlanta Braves', 'Chicago Cubs']
# ['Atlanta Braves', 'MVP']
# ['Atlanta Braves', 'Gold Glove']
# ['Seattle Mariners', 'Chicago Cubs']
# ['Seattle Mariners', 'MVP']
# ['Seattle Mariners', 'Gold Glove']
# ['Toronto Blue Jays', 'Chicago Cubs']
# ['Toronto Blue Jays', 'MVP']
# ['Toronto Blue Jays', 'Gold Glove']
# ['Seattle Mariners', 'Los Angeles Angels']
# ['Seattle Mariners', 'Cy Young']
# ['Seattle Mariners', 'Gold Glove']
# ['Cleveland Guardians', 'Los Angeles Angels']
# ['Cleveland Guardians', 'Cy Young']
# ['Cleveland Guardians', 'Gold Glove']
# ['Arizona Diamondbacks', 'Los Angeles Angels']
# ['Arizona Diamondbacks', 'Cy Young']
# ['Arizona Diamondbacks', 'Gold Glove']
# ['Kansas City Royals', 'Washington Nationals']
# ['Kansas City Royals', 'Cy Young']
# ['Kansas City Royals', 'Rookie of the Year']
# ['Cleveland Guardians', 'Washington Nationals']
# ['Cleveland Guardians', 'Cy Young']
# ['Cleveland Guardians', 'Rookie of the Year']
# ['Los Angeles Angels', 'Washington Nationals']
# ['Los Angeles Angels', 'Cy Young']
# ['Los Angeles Angels', 'Rookie of the Year']
# ['Washington Nationals', 'Chicago White Sox']
# ['Washington Nationals', 'World Series Champ WS Roster']
# ['Washington Nationals', 'Cy Young']
# ['Kansas City Royals', 'Chicago White Sox']
# ['Kansas City Royals', 'World Series Champ WS Roster']
# ['Kansas City Royals', 'Cy Young']
# ['Pittsburgh Pirates', 'Chicago White Sox']
# ['Pittsburgh Pirates', 'World Series Champ WS Roster']
# ['Pittsburgh Pirates', 'Cy Young']
# ['Cleveland Guardians', 'Seattle Mariners']
# ['Cleveland Guardians', 'All Star']
# ['Cleveland Guardians', 'Gold Glove']
# ['Milwaukee Brewers', 'Seattle Mariners']
# ['Milwaukee Brewers', 'All Star']
# ['Milwaukee Brewers', 'Gold Glove']
# ['New York Yankees', 'Seattle Mariners']
# ['New York Yankees', 'All Star']
# ['New York Yankees', 'Gold Glove']
# ['Cleveland Guardians', 'Boston Red Sox']
# ['Cleveland Guardians', 'Rookie of the Year']
# ['Cleveland Guardians', 'Silver Slugger']
# ['Toronto Blue Jays', 'Boston Red Sox']
# ['Toronto Blue Jays', 'Rookie of the Year']
# ['Toronto Blue Jays', 'Silver Slugger']
# ['Kansas City Royals', 'Boston Red Sox']
# ['Kansas City Royals', 'Rookie of the Year']
# ['Kansas City Royals', 'Silver Slugger']
# ['Kansas City Royals', 'Los Angeles Angels']
# ['Kansas City Royals', 'All Star']
# ['Kansas City Royals', 'Silver Slugger']
# ['Tampa Bay Rays', 'Los Angeles Angels']
# ['Tampa Bay Rays', 'All Star']
# ['Tampa Bay Rays', 'Silver Slugger']
# ['Boston Red Sox', 'Los Angeles Angels']
# ['Boston Red Sox', 'All Star']
# ['Boston Red Sox', 'Silver Slugger']
# ['San Diego Padres', 'Miami Marlins']
# ['San Diego Padres', 'Cy Young']
# ['San Diego Padres', 'All Star']
# ['New York Mets', 'Miami Marlins']
# ['New York Mets', 'Cy Young']
# ['New York Mets', 'All Star']
# ['Arizona Diamondbacks', 'Miami Marlins']
# ['Arizona Diamondbacks', 'Cy Young']
# ['Arizona Diamondbacks', 'All Star']
# ['New York Yankees', 'Detroit Tigers']
# ['New York Yankees', 'MVP']
# ['New York Yankees', 'Rookie of the Year']
# ['Los Angeles Angels', 'Detroit Tigers']
# ['Los Angeles Angels', 'MVP']
# ['Los Angeles Angels', 'Rookie of the Year']
# ['Oakland Athletics', 'Detroit Tigers']
# ['Oakland Athletics', 'MVP']
# ['Oakland Athletics', 'Rookie of the Year']
# ['Pittsburgh Pirates', 'Milwaukee Brewers']
# ['Pittsburgh Pirates', 'Rookie of the Year']
# ['Pittsburgh Pirates', 'MVP']
# ['Colorado Rockies', 'Milwaukee Brewers']
# ['Colorado Rockies', 'Rookie of the Year']
# ['Colorado Rockies', 'MVP']
# ['Detroit Tigers', 'Milwaukee Brewers']
# ['Detroit Tigers', 'Rookie of the Year']
# ['Detroit Tigers', 'MVP']
# ['Oakland Athletics', 'Baltimore Orioles']
# ['Oakland Athletics', 'Hall of Fame']
# ['Oakland Athletics', 'MVP']
# ['Los Angeles Dodgers', 'Baltimore Orioles']
# ['Los Angeles Dodgers', 'Hall of Fame']
# ['Los Angeles Dodgers', 'MVP']
# ['Chicago White Sox', 'Baltimore Orioles']
# ['Chicago White Sox', 'Hall of Fame']
# ['Chicago White Sox', 'MVP']
# ['St. Louis Cardinals', 'Colorado Rockies']
# ['St. Louis Cardinals', 'World Series Champ WS Roster']
# ['St. Louis Cardinals', 'Rookie of the Year']
# ['Kansas City Royals', 'Colorado Rockies']
# ['Kansas City Royals', 'World Series Champ WS Roster']
# ['Kansas City Royals', 'Rookie of the Year']
# ['Washington Nationals', 'Colorado Rockies']
# ['Washington Nationals', 'World Series Champ WS Roster']
# ['Washington Nationals', 'Rookie of the Year']
# ['St. Louis Cardinals', 'Philadelphia Phillies']
# ['St. Louis Cardinals', 'Silver Slugger']
# ['St. Louis Cardinals', 'Gold Glove']
# ['Los Angeles Dodgers', 'Philadelphia Phillies']
# ['Los Angeles Dodgers', 'Silver Slugger']
# ['Los Angeles Dodgers', 'Gold Glove']
# ['Kansas City Royals', 'Philadelphia Phillies']
# ['Kansas City Royals', 'Silver Slugger']
# ['Kansas City Royals', 'Gold Glove']
# ['Chicago White Sox', 'Houston Astros']
# ['Chicago White Sox', 'Hall of Fame']
# ['Chicago White Sox', 'Gold Glove']
# ['Philadelphia Phillies', 'Houston Astros']
# ['Philadelphia Phillies', 'Hall of Fame']
# ['Philadelphia Phillies', 'Gold Glove']
# ['Texas Rangers', 'Houston Astros']
# ['Texas Rangers', 'Hall of Fame']
# ['Texas Rangers', 'Gold Glove']
# ['Philadelphia Phillies', 'Arizona Diamondbacks']
# ['Philadelphia Phillies', 'MVP']
# ['Philadelphia Phillies', 'Rookie of the Year']
# ['San Diego Padres', 'Arizona Diamondbacks']
# ['San Diego Padres', 'MVP']
# ['San Diego Padres', 'Rookie of the Year']
# ['Atlanta Braves', 'Arizona Diamondbacks']
# ['Atlanta Braves', 'MVP']
# ['Atlanta Braves', 'Rookie of the Year']
# ['Tampa Bay Rays', 'Boston Red Sox']
# ['Tampa Bay Rays', 'Silver Slugger']
# ['Tampa Bay Rays', 'All Star']
# ['Los Angeles Angels', 'Boston Red Sox']
# ['Los Angeles Angels', 'Silver Slugger']
# ['Los Angeles Angels', 'All Star']
# ['Texas Rangers', 'Boston Red Sox']
# ['Texas Rangers', 'Silver Slugger']
# ['Texas Rangers', 'All Star']
# ['Atlanta Braves', 'Houston Astros']
# ['Atlanta Braves', 'All Star']
# ['Atlanta Braves', 'Rookie of the Year']
# ['Chicago White Sox', 'Houston Astros']
# ['Chicago White Sox', 'All Star']
# ['Chicago White Sox', 'Rookie of the Year']
# ['Los Angeles Angels', 'Houston Astros']
# ['Los Angeles Angels', 'All Star']
# ['Los Angeles Angels', 'Rookie of the Year']
# ['St. Louis Cardinals', 'Chicago Cubs']
# ['St. Louis Cardinals', 'Silver Slugger']
# ['St. Louis Cardinals', 'Rookie of the Year']
# ['Tampa Bay Rays', 'Chicago Cubs']
# ['Tampa Bay Rays', 'Silver Slugger']
# ['Tampa Bay Rays', 'Rookie of the Year']
# ['Colorado Rockies', 'Chicago Cubs']
# ['Colorado Rockies', 'Silver Slugger']
# ['Colorado Rockies', 'Rookie of the Year']
# ['Los Angeles Dodgers', 'Pittsburgh Pirates']
# ['Los Angeles Dodgers', 'Cy Young']
# ['Los Angeles Dodgers', 'Silver Slugger']
# ['Milwaukee Brewers', 'Pittsburgh Pirates']
# ['Milwaukee Brewers', 'Cy Young']
# ['Milwaukee Brewers', 'Silver Slugger']
# ['Chicago White Sox', 'Pittsburgh Pirates']
# ['Chicago White Sox', 'Cy Young']
# ['Chicago White Sox', 'Silver Slugger']
# ['Washington Nationals', 'Tampa Bay Rays']
# ['Washington Nationals', 'MVP']
# ['Washington Nationals', 'Rookie of the Year']
# ['Philadelphia Phillies', 'Tampa Bay Rays']
# ['Philadelphia Phillies', 'MVP']
# ['Philadelphia Phillies', 'Rookie of the Year']
# ['Toronto Blue Jays', 'Tampa Bay Rays']
# ['Toronto Blue Jays', 'MVP']
# ['Toronto Blue Jays', 'Rookie of the Year']
# ['Philadelphia Phillies', 'Boston Red Sox']
# ['Philadelphia Phillies', 'Silver Slugger']
# ['Philadelphia Phillies', 'Gold Glove']
# ['Chicago Cubs', 'Boston Red Sox']
# ['Chicago Cubs', 'Silver Slugger']
# ['Chicago Cubs', 'Gold Glove']
# ['Chicago White Sox', 'Boston Red Sox']
# ['Chicago White Sox', 'Silver Slugger']
# ['Chicago White Sox', 'Gold Glove']
# ['Cleveland Guardians', 'Philadelphia Phillies']
# ['Cleveland Guardians', 'Gold Glove']
# ['Cleveland Guardians', 'Cy Young']
# ['Detroit Tigers', 'Philadelphia Phillies']
# ['Detroit Tigers', 'Gold Glove']
# ['Detroit Tigers', 'Cy Young']
# ['San Francisco Giants', 'Philadelphia Phillies']
# ['San Francisco Giants', 'Gold Glove']
# ['San Francisco Giants', 'Cy Young']
# ['Seattle Mariners', 'Los Angeles Dodgers']
# ['Seattle Mariners', 'Silver Slugger']
# ['Seattle Mariners', 'Gold Glove']
# ['Boston Red Sox', 'Los Angeles Dodgers']
# ['Boston Red Sox', 'Silver Slugger']
# ['Boston Red Sox', 'Gold Glove']
# ['Baltimore Orioles', 'Los Angeles Dodgers']
# ['Baltimore Orioles', 'Silver Slugger']
# ['Baltimore Orioles', 'Gold Glove']
# ['Milwaukee Brewers', 'Seattle Mariners']
# ['Milwaukee Brewers', 'Silver Slugger']
# ['Milwaukee Brewers', 'All Star']
# ['Houston Astros', 'Seattle Mariners']
# ['Houston Astros', 'Silver Slugger']
# ['Houston Astros', 'All Star']
# ['Cincinnati Reds', 'Seattle Mariners']
# ['Cincinnati Reds', 'Silver Slugger']
# ['Cincinnati Reds', 'All Star']
# ['Texas Rangers', 'Philadelphia Phillies']
# ['Texas Rangers', 'All Star']
# ['Texas Rangers', 'Gold Glove']
# ['Chicago Cubs', 'Philadelphia Phillies']
# ['Chicago Cubs', 'All Star']
# ['Chicago Cubs', 'Gold Glove']
# ['Arizona Diamondbacks', 'Philadelphia Phillies']
# ['Arizona Diamondbacks', 'All Star']
# ['Arizona Diamondbacks', 'Gold Glove']
# ['San Francisco Giants', 'Houston Astros']
# ['San Francisco Giants', 'Cy Young']
# ['San Francisco Giants', 'Rookie of the Year']
# ['Tampa Bay Rays', 'Houston Astros']
# ['Tampa Bay Rays', 'Cy Young']
# ['Tampa Bay Rays', 'Rookie of the Year']
# ['Milwaukee Brewers', 'Houston Astros']
# ['Milwaukee Brewers', 'Cy Young']
# ['Milwaukee Brewers', 'Rookie of the Year']
# ['Kansas City Royals', 'San Diego Padres']
# ['Kansas City Royals', 'Hall of Fame']
# ['Kansas City Royals', 'All Star']
# ['Chicago Cubs', 'San Diego Padres']
# ['Chicago Cubs', 'Hall of Fame']
# ['Chicago Cubs', 'All Star']
# ['Cleveland Guardians', 'San Diego Padres']
# ['Cleveland Guardians', 'Hall of Fame']
# ['Cleveland Guardians', 'All Star']
# ['Detroit Tigers', 'New York Yankees']
# ['Detroit Tigers', 'Gold Glove']
# ['Detroit Tigers', 'Rookie of the Year']
# ['Oakland Athletics', 'New York Yankees']
# ['Oakland Athletics', 'Gold Glove']
# ['Oakland Athletics', 'Rookie of the Year']
# ['San Diego Padres', 'New York Yankees']
# ['San Diego Padres', 'Gold Glove']
# ['San Diego Padres', 'Rookie of the Year']
# ['Chicago White Sox', 'Cincinnati Reds']
# ['Chicago White Sox', 'Rookie of the Year']
# ['Chicago White Sox', 'Gold Glove']
# ['Pittsburgh Pirates', 'Cincinnati Reds']
# ['Pittsburgh Pirates', 'Rookie of the Year']
# ['Pittsburgh Pirates', 'Gold Glove']
# ['Philadelphia Phillies', 'Cincinnati Reds']
# ['Philadelphia Phillies', 'Rookie of the Year']
# ['Philadelphia Phillies', 'Gold Glove']
# ['Houston Astros', 'Chicago Cubs']
# ['Houston Astros', 'Gold Glove']
# ['Houston Astros', 'Hall of Fame']
# ['Minnesota Twins', 'Chicago Cubs']
# ['Minnesota Twins', 'Gold Glove']
# ['Minnesota Twins', 'Hall of Fame']
# ['Atlanta Braves', 'Chicago Cubs']
# ['Atlanta Braves', 'Gold Glove']
# ['Atlanta Braves', 'Hall of Fame']
# ['Texas Rangers', 'Boston Red Sox']
# ['Texas Rangers', 'Hall of Fame']
# ['Texas Rangers', 'Gold Glove']
# ['Cleveland Guardians', 'Boston Red Sox']
# ['Cleveland Guardians', 'Hall of Fame']
# ['Cleveland Guardians', 'Gold Glove']
# ['Toronto Blue Jays', 'Boston Red Sox']
# ['Toronto Blue Jays', 'Hall of Fame']
# ['Toronto Blue Jays', 'Gold Glove']
# ['New York Yankees', 'Seattle Mariners']
# ['New York Yankees', 'Cy Young']
# ['New York Yankees', 'World Series Champ WS Roster']
# ['Kansas City Royals', 'Seattle Mariners']
# ['Kansas City Royals', 'Cy Young']
# ['Kansas City Royals', 'World Series Champ WS Roster']
# ['Philadelphia Phillies', 'Seattle Mariners']
# ['Philadelphia Phillies', 'Cy Young']
# ['Philadelphia Phillies', 'World Series Champ WS Roster']
# ['Chicago Cubs', 'Cleveland Guardians']
# ['Chicago Cubs', 'Gold Glove']
# ['Chicago Cubs', 'Cy Young']
# ['Milwaukee Brewers', 'Cleveland Guardians']
# ['Milwaukee Brewers', 'Gold Glove']
# ['Milwaukee Brewers', 'Cy Young']
# ['New York Mets', 'Cleveland Guardians']
# ['New York Mets', 'Gold Glove']
# ['New York Mets', 'Cy Young']
# ['Texas Rangers', 'Baltimore Orioles']
# ['Texas Rangers', 'Silver Slugger']
# ['Texas Rangers', 'MVP']
# ['Miami Marlins', 'Baltimore Orioles']
# ['Miami Marlins', 'Silver Slugger']
# ['Miami Marlins', 'MVP']
# ['San Francisco Giants', 'Baltimore Orioles']
# ['San Francisco Giants', 'Silver Slugger']
# ['San Francisco Giants', 'MVP']
# ['Detroit Tigers', 'Minnesota Twins']
# ['Detroit Tigers', 'MVP']
# ['Detroit Tigers', 'Cy Young']
# ['Los Angeles Dodgers', 'Minnesota Twins']
# ['Los Angeles Dodgers', 'MVP']
# ['Los Angeles Dodgers', 'Cy Young']
# ['Atlanta Braves', 'Minnesota Twins']
# ['Atlanta Braves', 'MVP']
# ['Atlanta Braves', 'Cy Young']
# ['New York Yankees', 'Washington Nationals']
# ['New York Yankees', 'All Star']
# ['New York Yankees', 'World Series Champ WS Roster']
# ['Houston Astros', 'Washington Nationals']
# ['Houston Astros', 'All Star']
# ['Houston Astros', 'World Series Champ WS Roster']
# ['New York Mets', 'Washington Nationals']
# ['New York Mets', 'All Star']
# ['New York Mets', 'World Series Champ WS Roster']
# ['Texas Rangers', 'Toronto Blue Jays']
# ['Texas Rangers', 'Hall of Fame']
# ['Texas Rangers', 'All Star']
# ['Boston Red Sox', 'Toronto Blue Jays']
# ['Boston Red Sox', 'Hall of Fame']
# ['Boston Red Sox', 'All Star']
# ['Cincinnati Reds', 'Toronto Blue Jays']
# ['Cincinnati Reds', 'Hall of Fame']
# ['Cincinnati Reds', 'All Star']

# %%
sorted(lst_st)
# Out:
# ['.300+ AVG Career Batting',
#  '.300+ AVG Season Batting',
#  '10+ HR Season Batting',
#  '10+ Win Season Pitching',
#  '100+ RBI Season Batting',
#  '100+ Run Season Batting',
#  '20+ Win Season Pitching',
#  '200+ Hits Season Batting',
#  '200+ K Season Pitching',
#  '200+ Wins Career Pitching',
#  '2000+ Hits Career Batting',
#  '2000+ K Career Pitching',
#  '30+ HR / 30+ SB Season Batting',
#  '30+ HR Season Batting',
#  '30+ SB Season',
#  '30+ Save Season Pitching',
#  '300+ HR Career Batting',
#  '300+ Save Career Pitching',
#  '300+ Wins Career Pitching',
#  '3000+ Hits Career Batting',
#  '3000+ K Career Pitching',
#  '40+ 2B Season Batting',
#  '40+ HR Season Batting',
#  '40+ Save Season Pitching',
#  '40+ WAR Career',
#  '500+ HR Career Batting',
#  '6+ WAR Season',
#  'All Star',
#  'Arizona Diamondbacks',
#  'Atlanta Braves',
#  'Baltimore Orioles',
#  'Born Outside US 50 States and DC',
#  'Boston Red Sox',
#  'Canada',
#  'Chicago Cubs',
#  'Chicago White Sox',
#  'Cincinnati Reds',
#  'Cleveland Guardians',
#  'Colorado Rockies',
#  'Cy Young',
#  'Designated Hitter min. 1 game',
#  'Detroit Tigers',
#  'Dominican Republic',
#  'First Round Draft Pick',
#  'Gold Glove',
#  'Hall of Fame',
#  'Houston Astros',
#  'Kansas City Royals',
#  'Los Angeles Angels',
#  'Los Angeles Dodgers',
#  'MVP',
#  'Miami Marlins',
#  'Milwaukee Brewers',
#  'Minnesota Twins',
#  'New York Mets',
#  'New York Yankees',
#  'Oakland Athletics',
#  'Only One Team',
#  'Philadelphia Phillies',
#  'Pitched min. 1 game',
#  'Pittsburgh Pirates',
#  'Played Catcher min. 1 game',
#  'Played Center Field min. 1 game',
#  'Played First Base min. 1 game',
#  'Played In Major Negro Lgs',
#  'Played Left Field min. 1 game',
#  'Played Outfield min. 1 game',
#  'Played Right Field min. 1 game',
#  'Played Second Base min. 1 game',
#  'Played Shortstop min. 1 game',
#  'Played Third Base min. 1 game',
#  'Puerto Rico',
#  'Rookie of the Year',
#  'San Diego Padres',
#  'San Francisco Giants',
#  'Seattle Mariners',
#  'Silver Slugger',
#  'St. Louis Cardinals',
#  'Tampa Bay Rays',
#  'Texas Rangers',
#  'Threw a No-Hitter',
#  'Toronto Blue Jays',
#  'United States',
#  'Washington Nationals',
#  'World Series Champ WS Roster',
#  '≤ 3.00 ERA Career Pitching',
#  '≤ 3.00 ERA Season']

# %%
from fastapi import HTTPException, status
import os
import pymysql.cursors
from pymysql import converters


class DatabaseConnector:
    def __init__(self, db: str = "immaculateGrid"):
        self.host = os.getenv("DATABASE_HOST")
        self.user = os.getenv("DATABASE_USERNAME")
        self.password = os.getenv("DATABASE_PASSWORD")
        self.database = db
        self.port = int(os.getenv("DATABASE_PORT"))
        self.conversions = converters.conversions
        self.conversions[pymysql.FIELD_TYPE.BIT] = (
            lambda x: False if x == b"\x00" else True
        )
        if not self.host:
            raise EnvironmentError("DATABASE_HOST environment variable not found")
        if not self.user:
            raise EnvironmentError("DATABASE_USERNAME environment variable not found")
        if not self.password:
            raise EnvironmentError("DATABASE_PASSWORD environment variable not found")
        if not self.database:
            raise EnvironmentError("DATABASE environment variable not found")

    def get_connection(self):
        connection = pymysql.connect(
            host=self.host,
            port=self.port,
            user=self.user,
            password=self.password,
            database=self.database,
            cursorclass=pymysql.cursors.DictCursor,
            conv=self.conversions,
        )
        return connection

    def query_get(self, sql, param=None):
        try:
            connection = self.get_connection()
            with connection:
                with connection.cursor() as cursor:
                    cursor.execute(sql, param)
                    return cursor.fetchall()
        except Exception as e:
            raise HTTPException(
                status_code=status.HTTP_500_INTERNAL_SERVER_ERROR,
                detail="Database error: " + str(e),
            )

    def query_put(self, sql, param):
        try:
            connection = self.get_connection()
            with connection:
                with connection.cursor() as cursor:
                    cursor.execute(sql, param)
                    connection.commit()
                    return cursor.lastrowid
        except Exception as e:
            raise HTTPException(
                status_code=status.HTTP_500_INTERNAL_SERVER_ERROR,
                detail="Database error: " + str(e),
            )

# %%
from typing import Union
from pydantic import BaseModel

class BaseResponse(BaseModel):
    pass

class Team(BaseResponse):
    team_id: str

class Position(BaseResponse):
    position_id: str

class Statistic(BaseResponse):
    timeframe: str
    type: str
    stat: str
    value: int

class Award(BaseResponse):
    award: str

class PlayerAttribute(BaseResponse):
    attribute: str

class Other(BaseResponse):
    other: str

# %%
import os

os.environ['DATABASE_PORT'] = "3306"
os.environ['DATABASE_HOST'] = "localhost"
os.environ['DATABASE_USERNAME'] = "root"
os.environ['DATABASE_PASSWORD'] = "P4ssw0rd"

db = DatabaseConnector()

# %%
def parse_teamID(possible_team_name: str) -> Team | None:
    if possible_team_name == "Los Angeles Angels":
        return Team(team_id="LAA")

    lk_query = """
        SELECT teamID, teamName 
        FROM immaculateGrid.TeamAttribute
        WHERE year = 2022;
        """
    team_lk_dict = {
        team["teamID"]: team["teamName"]
        for team in db.query_get(lk_query)
    }
    
    id = team_lk_dict.get(possible_team_name, "")
    return Team(team_id=id) if id else None


def parse_postions(possible_pos_cond: str) -> Position | None:
    position_dict = {
        'Pitched min. 1 game': "P",
        'Played Catcher min. 1 game': "C", 
        'Played First Base min. 1 game': "1B", 
        'Played Second Base min. 1 game': "2B", 
        'Played Third Base min. 1 game': "3B",
        'Played Shortstop min. 1 game': "SS", 
        'Played Left Field min. 1 game': "LF", 
        'Played Center Field min. 1 game': "CF", 
        'Played Right Field min. 1 game': "RF",       
        'Played Outfield min. 1 game': "OF", 
        'Designated Hitter min. 1 game': "DH",
    }
    pos_key = position_dict.get(possible_pos_cond, "")
    if pos_key:
        return Position(position_id=pos_key)

# %%
parse_teamID("Played Catcher min. 1 game")

# %%
parse_postions("Played Catcher min. 1 game")
# Out:
# Position(position_id='C')

# %%
import re

def parse_statistic(description: str) -> Statistic:
    # Patterns to capture parts of the statistic
    pattern = re.compile(r'(\d+|\≤\d+)\s*(HR|SB|ERA|Hits|K|Wins|WAR|RBI|Run)\s*(Career|Season)\s*(Batting|Pitching)')
    match = pattern.match(description)
    
    if not match:
        return None
    
    value_str, stat_name, timeframe, stat_type = match.groups()
    
    # Clean value
    value = int(value_str.replace('≤', '').replace('+', ''))
    
    return Statistic(
        timeframe=timeframe,
        type=stat_type,
        stat=stat_name,
        value=value
    )

# %%
parse_statistic("≤ 3.00 ERA Career Pitching")

# %%
team_lk = db.query_get("""
        SELECT teamID, teamName 
        FROM immaculateGrid.TeamAttribute
        WHERE year = 2022;
        """)

# %%
# Out:
# {'ARI': 'Arizona Diamondbacks',
#  'ATL': 'Atlanta Braves',
#  'BAL': 'Baltimore Orioles',
#  'BOS': 'Boston Red Sox',
#  'CHA': 'Chicago White Sox',
#  'CHN': 'Chicago Cubs',
#  'CIN': 'Cincinnati Reds',
#  'CLE': 'Cleveland Guardians',
#  'COL': 'Colorado Rockies',
#  'DET': 'Detroit Tigers',
#  'HOU': 'Houston Astros',
#  'KCA': 'Kansas City Royals',
#  'LAA': 'Los Angeles Angels of Anaheim',
#  'LAN': 'Los Angeles Dodgers',
#  'MIA': 'Miami Marlins',
#  'MIL': 'Milwaukee Brewers',
#  'MIN': 'Minnesota Twins',
#  'NYA': 'New York Yankees',
#  'NYN': 'New York Mets',
#  'OAK': 'Oakland Athletics',
#  'PHI': 'Philadelphia Phillies',
#  'PIT': 'Pittsburgh Pirates',
#  'SDN': 'San Diego Padres',
#  'SEA': 'Seattle Mariners',
#  'SFN': 'San Francisco Giants',
#  'SLN': 'St. Louis Cardinals',
#  'TBA': 'Tampa Bay Rays',
#  'TEX': 'Texas Rangers',
#  'TOR': 'Toronto Blue Jays',
#  'WAS': 'Washington Nationals'}
